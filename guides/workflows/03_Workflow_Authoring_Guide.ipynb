# %% [markdown]
# # Workflow Authoring Guide
#
# Placeholder for writing workflow-level documentation.
#
# ## To Add
#
# - Workflow ID conventions.
# - DBTL stage mapping.
# - Required inputs and outputs.
# - Robot and labware requirements.
# - Validation and simulation records.
