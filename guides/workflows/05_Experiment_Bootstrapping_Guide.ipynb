# %% [markdown]
# # Experiment Bootstrapping Guide
#
# Placeholder for creating a new experiment from an existing workflow.
#
# ## To Add
#
# - Branch and folder setup.
# - Experiment metadata.
# - Plate map creation.
# - Simulation and review steps.
# - Run-record expectations.
