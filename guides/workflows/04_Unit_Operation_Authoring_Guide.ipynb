# %% [markdown]
# # Unit Operation Authoring Guide
#
# Placeholder for designing reusable unit operations.
#
# ## To Add
#
# - Unit operation ID conventions.
# - Input parameter standards.
# - Validation expectations.
# - Opentrons implementation patterns.
# - Testing and simulation expectations.
