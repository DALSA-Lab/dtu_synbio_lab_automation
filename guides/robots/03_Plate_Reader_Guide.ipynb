# %% [markdown]
# # Plate Reader Guide
#
# Placeholder for plate-reader handoff and data-export procedures.
#
# ## To Add
#
# - Supported plate-reader models.
# - Plate orientation conventions.
# - File naming and metadata requirements.
# - Export formats.
# - QC checklist.
