# %% [markdown]
# # 01 Building your first protocol

# %% [markdown]
# Goal: Write, simulate, and understand your first complete OT-2 protocol.
#
# Suggested flow:
#
# Recap: short 3-line refresher on what the OT-2 is.
#
# Template structure: minimal example with metadata and run() function.
#
# Step-by-step explanation of:
#
# Loading labware
#
# Loading pipettes
#
# Transferring liquid
#
# Run a simulation (opentrons_simulate)
#
# Common errors and fixes
#
# Practice exercises: change labware slot, use a multi pipette, adjust flow rates.
