# %% [markdown]
# # Opentrons Flex Guide
#
# Placeholder for Opentrons Flex setup, calibration, module configuration, gripper use, protocol upload, simulation checks, run monitoring, cleanup, and troubleshooting.
#
# ## To Add
#
# - Supported deck configurations.
# - Pipette and tip compatibility.
# - Module-specific setup notes.
# - Pre-run checklist.
# - Common failure modes.
