# %% [markdown]
# # Thermocycler Guide
#
# Placeholder for thermocycler setup and handoff steps.
#
# ## To Add
#
# - Supported thermocycler models.
# - Sealing and lid-temperature notes.
# - Program naming conventions.
# - Manual handoff checklist.
# - Post-run handling.
